# %% [markdown]
# ### Import Data and Required Packages

# %%
# %pip install nltk

import nltk
from nltk.stem import PorterStemmer
import numpy as np 
import pandas as pd
# Out:
# Requirement already satisfied: nltk in c:\Users\dakid\Downloads\Projects\CineMatch\venv\Lib\site-packages (3.9.3)
# Requirement already satisfied: click in c:\Users\dakid\Downloads\Projects\CineMatch\venv\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in c:\Users\dakid\Downloads\Projects\CineMatch\venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\Users\dakid\Downloads\Projects\CineMatch\venv\Lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in c:\Users\dakid\Downloads\Projects\CineMatch\venv\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in c:\Users\dakid\Downloads\Projects\CineMatch\venv\Lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import the CSV Data as Pandas DataFrame

# %%
df = pd.read_csv('../data/TMDB_top25k.csv')

# %%
df.head(2)
# Out:
#    movie_id         title                                           overview  \
# 0    157336  Interstellar  The adventures of a group of explorers who mak...
# 1     27205     Inception  Cobb, a skilled thief who commits corporate es...
#
#                                       genres  \
# 0   ['Adventure', 'Drama', 'ScienceFiction']
# 1  ['Action', 'ScienceFiction', 'Adventure']
#
#                                             keywords  \
# 0  ['rescue', 'future', 'spacecraft', 'raceagains...
# 1  ['mission', 'dreams', 'kidnapping', 'spy', 'al...
#
#                                                 cast                  crew  \
# 0  ['MatthewMcConaughey', 'AnneHathaway', 'Michae...  ['ChristopherNolan']
# 1  ['LeonardoDiCaprio', 'JosephGordon-Levitt', 'K...  ['ChristopherNolan']
#
#   original_language  vote_average                      production_countries
# 0                en          8.50  United Kingdom, United States of America
# 1                en          8.37  United Kingdom, United States of America

# %%
print(df.columns)
# Out:
# Index(['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew',
#        'original_language', 'vote_average', 'production_countries'],
#       dtype='str')

# %%
movies = df[['movie_id', 'title', 'overview', 'genres', 'keywords', 'cast', 'crew', 'original_language', 'vote_average']]

# %%
movies.head()
# Out:
#    movie_id            title  \
# 0    157336     Interstellar
# 1     27205        Inception
# 2     24428     The Avengers
# 3       155  The Dark Knight
# 4     19995           Avatar
#
#                                             overview  \
# 0  The adventures of a group of explorers who mak...
# 1  Cobb, a skilled thief who commits corporate es...
# 2  When an unexpected enemy emerges and threatens...
# 3  Batman raises the stakes in his war on crime. ...
# 4  In the 22nd century, a paraplegic Marine is di...
#
#                                               genres  \
# 0           ['Adventure', 'Drama', 'ScienceFiction']
# 1          ['Action', 'ScienceFiction', 'Adventure']
# 2          ['ScienceFiction', 'Action', 'Adventure']
# 3                    ['Action', 'Crime', 'Thriller']
# 4  ['Action', 'Adventure', 'Fantasy', 'ScienceFic...
#
#                                             keywords  \
# 0  ['rescue', 'future', 'spacecraft', 'raceagains...
# 1  ['mission', 'dreams', 'kidnapping', 'spy', 'al...
# 2  ['newyorkcity', 'superhero', 'shield', 'basedo...
# 3  ['sadism', 'chaos', 'secretidentity', 'crimefi...
# 4  ['paraplegic', 'attachmenttonature', 'culturec...
#
#                                                 cast                  crew  \
# 0  ['MatthewMcConaughey', 'AnneHathaway', 'Michae...  ['ChristopherNolan']
# 1  ['LeonardoDiCaprio', 'JosephGordon-Levitt', 'K...  ['ChristopherNolan']
# 2   ['RobertDowneyJr.', 'ChrisEvans', 'MarkRuffalo']        ['JossWhedon']
# 3   ['ChristianBale', 'HeathLedger', 'AaronEckhart']  ['ChristopherNolan']
# 4  ['SamWorthington', 'ZoeSaldaña', 'SigourneyWea...      ['JamesCameron']
#
#   original_language  vote_average
# 0                en         8.500
# 1                en         8.370
# 2                en         7.942
# 3                en         8.526
# 4                en         7.600

# %% [markdown]
# ### Coverting all columns into list

# %%
import ast

def convert_to_list(text):
    try:
        return ast.literal_eval(text)
    except:
        return []

movies['genres'] = movies['genres'].apply(convert_to_list)
movies['keywords'] = movies['keywords'].apply(convert_to_list)
movies['cast'] = movies['cast'].apply(convert_to_list)
movies['crew'] = movies['crew'].apply(convert_to_list)

print("✅ Done")
# Out:
# ✅ Done

# %%
movies['keywords'] = movies['keywords'].apply(lambda x: x[0:5])
movies.head()
# Out:
#    movie_id            title  \
# 0    157336     Interstellar
# 1     27205        Inception
# 2     24428     The Avengers
# 3       155  The Dark Knight
# 4     19995           Avatar
#
#                                             overview  \
# 0  The adventures of a group of explorers who mak...
# 1  Cobb, a skilled thief who commits corporate es...
# 2  When an unexpected enemy emerges and threatens...
# 3  Batman raises the stakes in his war on crime. ...
# 4  In the 22nd century, a paraplegic Marine is di...
#
#                                          genres  \
# 0            [Adventure, Drama, ScienceFiction]
# 1           [Action, ScienceFiction, Adventure]
# 2           [ScienceFiction, Action, Adventure]
# 3                     [Action, Crime, Thriller]
# 4  [Action, Adventure, Fantasy, ScienceFiction]
#
#                                             keywords  \
# 0  [rescue, future, spacecraft, raceagainsttime, ...
# 1       [mission, dreams, kidnapping, spy, allegory]
# 2  [newyorkcity, superhero, shield, basedoncomic,...
# 3  [sadism, chaos, secretidentity, crimefighter, ...
# 4  [paraplegic, attachmenttonature, cultureclash,...
#
#                                                 cast                crew  \
# 0   [MatthewMcConaughey, AnneHathaway, MichaelCaine]  [ChristopherNolan]
# 1  [LeonardoDiCaprio, JosephGordon-Levitt, KenWat...  [ChristopherNolan]
# 2         [RobertDowneyJr., ChrisEvans, MarkRuffalo]        [JossWhedon]
# 3         [ChristianBale, HeathLedger, AaronEckhart]  [ChristopherNolan]
# 4      [SamWorthington, ZoeSaldaña, SigourneyWeaver]      [JamesCameron]
#
#   original_language  vote_average
# 0                en         8.500
# 1                en         8.370
# 2                en         7.942
# 3                en         8.526
# 4                en         7.600

# %%
movies.iloc[0]['keywords']
# Out:
# ['rescue',
#  'future',
#  'spacecraft',
#  'raceagainsttime',
#  'artificialintelligence(a.i.)']

# %%
movies.shape
# Out:
# (25000, 9)

# %% [markdown]
# ### Check Missing values

# %%
movies.isnull().sum()
# Out:
# movie_id              0
# title                 0
# overview             28
# genres                0
# keywords              0
# cast                  0
# crew                  0
# original_language     0
# vote_average          0
# dtype: int64

# %%
movies.dropna(inplace=True)
movies.reset_index(drop=True, inplace=True)

# %%
movies.shape
# Out:
# (24972, 9)

# %%
movies.isnull().sum()
# Out:
# movie_id             0
# title                0
# overview             0
# genres               0
# keywords             0
# cast                 0
# crew                 0
# original_language    0
# vote_average         0
# dtype: int64

# %% [markdown]
# ### Check data types

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24972 entries, 0 to 24971
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           24972 non-null  int64
#  1   title              24972 non-null  str
#  2   overview           24972 non-null  str
#  3   genres             24972 non-null  object
#  4   keywords           24972 non-null  object
#  5   cast               24972 non-null  object
#  6   crew               24972 non-null  object
#  7   original_language  24972 non-null  str
#  8   vote_average       24972 non-null  float64
# dtypes: float64(1), int64(1), object(4), str(3)
# memory usage: 1.7+ MB

# %% [markdown]
# ### handle overview (converting to list)

# %%
movies.iloc[0]['overview']
# Out:
# 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.'

# %%
movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.sample(4)
# Out:
#        movie_id                title  \
# 21618    227933               Alemao
# 21323     13957     Closing the Ring
# 18663    150273           The Return
# 11463     29452  The Face of Another
#
#                                                 overview  \
# 21618  [Five, undercover, cops, at, Complexo, do, Ale...
# 21323  [During, the, 1940s,, a, group, of, young, men...
# 18663  [Two, young, children, and, an, adult, in, a, ...
# 11463  [A, businessman, with, a, disfigured, face, ob...
#
#                                     genres  \
# 21618               [Action, Drama, Crime]
# 21323                     [Drama, Romance]
# 18663  [Mystery, Thriller, ScienceFiction]
# 11463              [Drama, ScienceFiction]
#
#                                                 keywords  \
# 21618                                                 []
# 21323      [airplane, worldwarii, bomber, love, soldier]
# 18663  [sheriff, alien, alienabduction, cattlemutilat...
# 11463  [mask, japan, dualidentity, basedonnovelorbook...
#
#                                                     cast  \
# 21618     [CaioBlat, GabrielBragaNunes, MarceloMelloJr.]
# 21323  [ShirleyMacLaine, ChristopherPlummer, MischaBa...
# 18663  [Jan-MichaelVincent, CybillShepherd, MartinLan...
# 11463         [TatsuyaNakadai, MikijiroHira, MachikoKyō]
#
#                         crew original_language  vote_average
# 21618  [JoséEduardoBelmonte]                en           6.2
# 21323  [RichardAttenborough]                en           6.1
# 18663         [GreydonClark]                en           5.9
# 11463   [HiroshiTeshigahara]                ja           7.8

# %%
movies.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24972 entries, 0 to 24971
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           24972 non-null  int64
#  1   title              24972 non-null  str
#  2   overview           24972 non-null  object
#  3   genres             24972 non-null  object
#  4   keywords           24972 non-null  object
#  5   cast               24972 non-null  object
#  6   crew               24972 non-null  object
#  7   original_language  24972 non-null  str
#  8   vote_average       24972 non-null  float64
# dtypes: float64(1), int64(1), object(5), str(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Concatinate all Columns

# %%
movies['tags'] = movies['overview'] + (movies['keywords'] * 4) + (movies['genres'] * 4) + (movies['cast'] * 3) + (movies['crew'] * 3)

# %%
movies.head()
# Out:
#    movie_id            title  \
# 0    157336     Interstellar
# 1     27205        Inception
# 2     24428     The Avengers
# 3       155  The Dark Knight
# 4     19995           Avatar
#
#                                             overview  \
# 0  [The, adventures, of, a, group, of, explorers,...
# 1  [Cobb,, a, skilled, thief, who, commits, corpo...
# 2  [When, an, unexpected, enemy, emerges, and, th...
# 3  [Batman, raises, the, stakes, in, his, war, on...
# 4  [In, the, 22nd, century,, a, paraplegic, Marin...
#
#                                          genres  \
# 0            [Adventure, Drama, ScienceFiction]
# 1           [Action, ScienceFiction, Adventure]
# 2           [ScienceFiction, Action, Adventure]
# 3                     [Action, Crime, Thriller]
# 4  [Action, Adventure, Fantasy, ScienceFiction]
#
#                                             keywords  \
# 0  [rescue, future, spacecraft, raceagainsttime, ...
# 1       [mission, dreams, kidnapping, spy, allegory]
# 2  [newyorkcity, superhero, shield, basedoncomic,...
# 3  [sadism, chaos, secretidentity, crimefighter, ...
# 4  [paraplegic, attachmenttonature, cultureclash,...
#
#                                                 cast                crew  \
# 0   [MatthewMcConaughey, AnneHathaway, MichaelCaine]  [ChristopherNolan]
# 1  [LeonardoDiCaprio, JosephGordon-Levitt, KenWat...  [ChristopherNolan]
# 2         [RobertDowneyJr., ChrisEvans, MarkRuffalo]        [JossWhedon]
# 3         [ChristianBale, HeathLedger, AaronEckhart]  [ChristopherNolan]
# 4      [SamWorthington, ZoeSaldaña, SigourneyWeaver]      [JamesCameron]
#
#   original_language  vote_average  \
# 0                en         8.500
# 1                en         8.370
# 2                en         7.942
# 3                en         8.526
# 4                en         7.600
#
#                                                 tags
# 0  [The, adventures, of, a, group, of, explorers,...
# 1  [Cobb,, a, skilled, thief, who, commits, corpo...
# 2  [When, an, unexpected, enemy, emerges, and, th...
# 3  [Batman, raises, the, stakes, in, his, war, on...
# 4  [In, the, 22nd, century,, a, paraplegic, Marin...

# %%
movies.iloc[0]['tags']
# Out:
# ['The',
#  'adventures',
#  'of',
#  'a',
#  'group',
#  'of',
#  'explorers',
#  'who',
#  'make',
#  'use',
#  'of',
#  'a',
#  'newly',
#  'discovered',
#  'wormhole',
#  'to',
#  'surpass',
#  'the',
#  'limitations',
#  'on',
#  'human',
#  'space',
#  'travel',
#  'and',
#  'conquer',
#  'the',
#  'vast',
#  'distances',
#  'involved',
#  'in',
#  'an',
#  'interstellar',
#  'voyage.',
#  'rescue',
#  'future',
#  'spacecraft',
#  'raceagainsttime',
#  'artificialintelligence(a.i.)',
#  'rescue',
#  'future',
#  'spacecraft',
#  'raceagainsttime',
#  'artificialintelligence(a.i.)',
#  'rescue',
#  'future',
#  'spacecraft',
#  'raceagainsttime',
#  'artificialintelligence(a.i.)',
#  'rescue',
#  'future',
#  'spacecraft',
#  'raceagainsttime',
#  'artificialintelligence(a.i.)',
#  'Adventure',
#  'Drama',
#  'ScienceFiction',
#  'Adventure',
#  'Drama',
#  'ScienceFiction',
#  'Adventure',
#  'Drama',
#  'ScienceFiction',
#  'Adventure',
#  'Drama',
#  'ScienceFiction',
#  'MatthewMcConaughey',
#  'AnneHathaway',
#  'MichaelCaine',
#  'MatthewMcConaughey',
#  'AnneHathaway',
#  'MichaelCaine',
#  'MatthewMcConaughey',
#  'AnneHathaway',
#  'MichaelCaine',
#  'ChristopherNolan',
#  'ChristopherNolan',
#  'ChristopherNolan']

# %% [markdown]
# ### droping those extra columns

# %%
new_df = movies[['movie_id', 'title', 'tags', 'original_language', 'vote_average']]

# %%
new_df.head()
# Out:
#    movie_id            title  \
# 0    157336     Interstellar
# 1     27205        Inception
# 2     24428     The Avengers
# 3       155  The Dark Knight
# 4     19995           Avatar
#
#                                                 tags original_language  \
# 0  [The, adventures, of, a, group, of, explorers,...                en
# 1  [Cobb,, a, skilled, thief, who, commits, corpo...                en
# 2  [When, an, unexpected, enemy, emerges, and, th...                en
# 3  [Batman, raises, the, stakes, in, his, war, on...                en
# 4  [In, the, 22nd, century,, a, paraplegic, Marin...                en
#
#    vote_average
# 0         8.500
# 1         8.370
# 2         7.942
# 3         8.526
# 4         7.600

# %% [markdown]
# ### Converting list to str

# %%
new_df['tags'] = new_df['tags'].apply(lambda x: " ".join(x))
new_df.head()
# Out:
#    movie_id            title  \
# 0    157336     Interstellar
# 1     27205        Inception
# 2     24428     The Avengers
# 3       155  The Dark Knight
# 4     19995           Avatar
#
#                                                 tags original_language  \
# 0  The adventures of a group of explorers who mak...                en
# 1  Cobb, a skilled thief who commits corporate es...                en
# 2  When an unexpected enemy emerges and threatens...                en
# 3  Batman raises the stakes in his war on crime. ...                en
# 4  In the 22nd century, a paraplegic Marine is di...                en
#
#    vote_average
# 0         8.500
# 1         8.370
# 2         7.942
# 3         8.526
# 4         7.600

# %%
new_df.iloc[0]['tags']
# Out:
# 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage. rescue future spacecraft raceagainsttime artificialintelligence(a.i.) rescue future spacecraft raceagainsttime artificialintelligence(a.i.) rescue future spacecraft raceagainsttime artificialintelligence(a.i.) rescue future spacecraft raceagainsttime artificialintelligence(a.i.) Adventure Drama ScienceFiction Adventure Drama ScienceFiction Adventure Drama ScienceFiction Adventure Drama ScienceFiction MatthewMcConaughey AnneHathaway MichaelCaine MatthewMcConaughey AnneHathaway MichaelCaine MatthewMcConaughey AnneHathaway MichaelCaine ChristopherNolan ChristopherNolan ChristopherNolan'

# %% [markdown]
# ### Converting to lower case

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#    movie_id            title  \
# 0    157336     Interstellar
# 1     27205        Inception
# 2     24428     The Avengers
# 3       155  The Dark Knight
# 4     19995           Avatar
#
#                                                 tags original_language  \
# 0  the adventures of a group of explorers who mak...                en
# 1  cobb, a skilled thief who commits corporate es...                en
# 2  when an unexpected enemy emerges and threatens...                en
# 3  batman raises the stakes in his war on crime. ...                en
# 4  in the 22nd century, a paraplegic marine is di...                en
#
#    vote_average
# 0         8.500
# 1         8.370
# 2         7.942
# 3         8.526
# 4         7.600

# %%
new_df.iloc[0]['tags']
# Out:
# 'the adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage. rescue future spacecraft raceagainsttime artificialintelligence(a.i.) rescue future spacecraft raceagainsttime artificialintelligence(a.i.) rescue future spacecraft raceagainsttime artificialintelligence(a.i.) rescue future spacecraft raceagainsttime artificialintelligence(a.i.) adventure drama sciencefiction adventure drama sciencefiction adventure drama sciencefiction adventure drama sciencefiction matthewmcconaughey annehathaway michaelcaine matthewmcconaughey annehathaway michaelcaine matthewmcconaughey annehathaway michaelcaine christophernolan christophernolan christophernolan'

# %% [markdown]
# ### Word Stemming (Simplifying Words)
# We use `PorterStemmer` to cut down words to their base root.
# For example, the words **'action'**, **'actions'**, and **'actionable'** all mean the exact same thing. But a computer might treat them as 3 completely different words.
# Stemming cuts them all down to just **'action'**. This helps the model realize they mean the same thing and improves our movie recommendations!

# %%
from nltk.stem.porter import PorterStemmer   
ps = PorterStemmer()

# %%
def stems(text):
    T = []
    
    for i in text.split():
        T.append(ps.stem(i))
    
    return " ".join(T)

# %%
new_df['tags'] = new_df['tags'].apply(stems)

# %%
new_df.iloc[0]['tags']
# Out:
# 'the adventur of a group of explor who make use of a newli discov wormhol to surpass the limit on human space travel and conquer the vast distanc involv in an interstellar voyage. rescu futur spacecraft raceagainsttim artificialintelligence(a.i.) rescu futur spacecraft raceagainsttim artificialintelligence(a.i.) rescu futur spacecraft raceagainsttim artificialintelligence(a.i.) rescu futur spacecraft raceagainsttim artificialintelligence(a.i.) adventur drama sciencefict adventur drama sciencefict adventur drama sciencefict adventur drama sciencefict matthewmcconaughey annehathaway michaelcain matthewmcconaughey annehathaway michaelcain matthewmcconaughey annehathaway michaelcain christophernolan christophernolan christophernolan'

# %% [markdown]
# ### Vectorization: Converting Text to Numbers

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(
    max_features=15000,
    stop_words='english',
    ngram_range=(1, 2),   
    min_df=2,
    sublinear_tf=True     
)

# %%
vectors = tfidf.fit_transform(new_df['tags'])

# %%
vectors[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 31 stored elements and shape (1, 15000)>

# %%
vectors.shape
# Out:
# (24972, 15000)

# %%
len(tfidf.get_feature_names_out())
# Out:
# 15000

# %% [markdown]
# ### Finding the Most Similar Movies (Cosine Similarity)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)
print(similarity)
# Out:
# [[1.         0.20308077 0.03530164 ... 0.00382361 0.02250723 0.00598856]
#  [0.20308077 1.         0.04010071 ... 0.03603466 0.03733457 0.00537003]
#  [0.03530164 0.04010071 1.         ... 0.02948085 0.04363772 0.        ]
#  ...
#  [0.00382361 0.03603466 0.02948085 ... 1.         0.05730514 0.0322558 ]
#  [0.02250723 0.03733457 0.04363772 ... 0.05730514 1.         0.02338956]
#  [0.00598856 0.00537003 0.         ... 0.0322558  0.02338956 1.        ]]

# %%
similarity.shape
# Out:
# (24972, 24972)

# %%
new_df[new_df['title'] == 'The Lego Movie'].index[0]
# Out:
# 486

# %%
def recommend(movie):
    index = new_df[new_df['title'] == movie].index[0]
    distances = sorted(list(enumerate(similarity[index])),reverse=True,key = lambda x: x[1])
    for i in distances[1:11]:
        print(new_df.iloc[i[0]].title)

# %%
recommend('Insidious')
# Out:
# Insidious: Chapter 2
# Insidious: The Red Door
# Insidious: Chapter 3
# Insidious: The Last Key
# The Medium
# The Conjuring
# The Vigil
# The Toybox
# Saw
# Room for Rent

# %% [markdown]
# ### Exporting the Model

# %%
import pickle
import scipy.sparse as sp

# Save movies dataframe
pickle.dump(new_df.to_dict(), open('../models/movie_dict.pkl', 'wb'))

# Save sparse vectors
sp.save_npz('../models/vectors.npz', vectors)
